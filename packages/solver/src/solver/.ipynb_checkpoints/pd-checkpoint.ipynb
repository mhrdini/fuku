# %%
import pandas as pd
import re

# %%
df = pd.read_json('result.json')

if 'assignments' in df.columns:
    df = pd.json_normalize(df['assignments'])

if 'score' in df.columns:
    df = df[['date', 'teamMemberId', 'shiftTypeId', 'score']]
else:
    df = df[['date', 'teamMemberId', 'shiftTypeId']]

# %%
members = df['teamMemberId'].unique()
print(members)
# Out:
# <StringArray>
# ['tmptf003-0000-0000-0000-000000000008',
#  'tmptf002-0000-0000-0000-000000000007',
#  'tmptf001-0000-0000-0000-000000000006',
#  'tmstf004-0000-0000-0000-000000000005',
#  'tmstf003-0000-0000-0000-000000000004',
#  'tmstf002-0000-0000-0000-000000000003',
#  'tmstf001-0000-0000-0000-000000000002',
#  'tmadm000-0000-0000-0000-000000000001']
# Length: 8, dtype: str

# %%
prefix_map = {
    "ptf": "P",
    "stf": "F",
    "adm": "M"
}

member_map = {}
for member in members:
    # remove 'tm' prefix
    id_core = member[2:8]
    # get sections
    letters = id_core[:3]
    number = id_core[3:]
    # remove leading zeros
    number = str(int(number))
    member_map[member] = prefix_map[letters] + number

print(member_map)
# Out:
# {'tmptf003-0000-0000-0000-000000000008': 'P3', 'tmptf002-0000-0000-0000-000000000007': 'P2', 'tmptf001-0000-0000-0000-000000000006': 'P1', 'tmstf004-0000-0000-0000-000000000005': 'F4', 'tmstf003-0000-0000-0000-000000000004': 'F3', 'tmstf002-0000-0000-0000-000000000003': 'F2', 'tmstf001-0000-0000-0000-000000000002': 'F1', 'tmadm000-0000-0000-0000-000000000001': 'M0'}

# %%
shifts = df['shiftTypeId'].unique()

shift_map = {}
for shift in shifts:
    # Take first 7 chars (e.g., 'stP00000')
    code = shift[:7]
    # Extract only capital letters
    letters = ''.join(re.findall(r'[A-Z]+', code))
    shift_map[shift] = letters

print(shift_map)
# Out:
# {'stBB0000-0000-0000-0000-000000000004': 'BB', 'stP00000-0000-0000-0000-000000000005': 'P', 'stA00000-0000-0000-0000-000000000002': 'A', 'stB00000-0000-0000-0000-000000000003': 'B', 'stAA0000-0000-0000-0000-000000000001': 'AA'}

# %%
df['teamMemberId'] = df['teamMemberId'].map(member_map)
df['shiftTypeId'] = df['shiftTypeId'].map(shift_map)

# %%
df['date'] = pd.to_datetime(df['date'])
df['date'] = df['date'].dt.tz_convert('Asia/Tokyo')
df['date'] = df['date'].dt.date
display(df)
# Out:
#            date teamMemberId shiftTypeId
# 0    2026-02-01           P3          BB
# 1    2026-02-06           P3           P
# 2    2026-02-07           P3           P
# 3    2026-02-09           P3          BB
# 4    2026-02-13           P3           P
# ..          ...          ...         ...
# 123  2026-02-16           M0          AA
# 124  2026-02-19           M0          AA
# 125  2026-02-22           M0           B
# 126  2026-02-23           M0           B
# 127  2026-02-28           M0          AA
#
# [128 rows x 3 columns]

# %%
dfs = df.sort_values(
    by=['date', 'teamMemberId', 'shiftTypeId']
).reset_index(drop=True)

display(dfs)
# Out:
#            date teamMemberId shiftTypeId
# 0    2026-02-01           F3           A
# 1    2026-02-01           F4          AA
# 2    2026-02-01           M0          BB
# 3    2026-02-01           P1          BB
# 4    2026-02-01           P2          BB
# ..          ...          ...         ...
# 123  2026-02-28           F4          AA
# 124  2026-02-28           M0          AA
# 125  2026-02-28           P1          BB
# 126  2026-02-28           P2          BB
# 127  2026-02-28           P3          BB
#
# [128 rows x 3 columns]

# %%
grouped = df.groupby('date')
for date, group in grouped:
    display(group.sort_values(['teamMemberId', 'shiftTypeId']))
# Out:
#            date teamMemberId shiftTypeId
# 52   2026-02-01           F3           A
# 33   2026-02-01           F4          AA
# 109  2026-02-01           M0          BB
# 22   2026-02-01           P1          BB
# 11   2026-02-01           P2          BB
# 0    2026-02-01           P3          BB
#            date teamMemberId shiftTypeId
# 90   2026-02-02           F1           A
# 53   2026-02-02           F3           A
# 34   2026-02-02           F4          AA
# 110  2026-02-02           M0          BB
#            date teamMemberId shiftTypeId
# 91   2026-02-03           F1           A
# 35   2026-02-03           F4          AA
# 111  2026-02-03           M0          BB
# 23   2026-02-03           P1          BB
#            date teamMemberId shiftTypeId
# 71   2026-02-04           F2           A
# 54   2026-02-04           F3          AA
# 36   2026-02-04           F4          AA
# 112  2026-02-04           M0          BB
#            date teamMemberId shiftTypeId
# 92   2026-02-05           F1          AA
# 72   2026-02-05           F2           A
# 55   2026-02-05           F3          AA
# 113  2026-02-05           M0          BB
#            date teamMemberId shiftTypeId
# 56   2026-02-06           F3          AA
# 114  2026-02-06           M0          BB
# 12   2026-02-06           P2          BB
# 1    2026-02-06           P3           P
#            date teamMemberId shiftTypeId
# 93   2026-02-07           F1           B
# 73   2026-02-07           F2          BB
# 57   2026-02-07           F3          AA
# 37   2026-02-07           F4          AA
# 115  2026-02-07           M0          BB
# 2    2026-02-07           P3           P
#            date teamMemberId shiftTypeId
# 94   2026-02-08           F1           B
# 74   2026-02-08           F2          BB
# 58   2026-02-08           F3          AA
# 38   2026-02-08           F4          AA
# 116  2026-02-08           M0          BB
# 24   2026-02-08           P1          BB
#            date teamMemberId shiftTypeId
# 39   2026-02-09           F4          AA
# 117  2026-02-09           M0          BB
# 13   2026-02-09           P2           B
# 3    2026-02-09           P3          BB
#           date teamMemberId shiftTypeId
# 95  2026-02-10           F1          AA
# 75  2026-02-10           F2          AA
# 59  2026-02-10           F3          AA
# 25  2026-02-10           P1           P
#            date teamMemberId shiftTypeId
# 96   2026-02-11           F1          AA
# 76   2026-02-11           F2          AA
# 60   2026-02-11           F3          AA
# 118  2026-02-11           M0          AA
#            date teamMemberId shiftTypeId
# 97   2026-02-12           F1          AA
# 77   2026-02-12           F2          AA
# 119  2026-02-12           M0          AA
# 26   2026-02-12           P1           P
#            date teamMemberId shiftTypeId
# 40   2026-02-13           F4          AA
# 120  2026-02-13           M0          AA
# 14   2026-02-13           P2          BB
# 4    2026-02-13           P3           P
#            date teamMemberId shiftTypeId
# 98   2026-02-14           F1          AA
# 78   2026-02-14           F2          AA
# 61   2026-02-14           F3          AA
# 41   2026-02-14           F4          AA
# 121  2026-02-14           M0          AA
# 5    2026-02-14           P3           P
#            date teamMemberId shiftTypeId
# 99   2026-02-15           F1          AA
# 79   2026-02-15           F2          AA
# 62   2026-02-15           F3          AA
# 42   2026-02-15           F4          AA
# 122  2026-02-15           M0          AA
# 27   2026-02-15           P1           P
#            date teamMemberId shiftTypeId
# 63   2026-02-16           F3          AA
# 43   2026-02-16           F4          AA
# 123  2026-02-16           M0          AA
# 15   2026-02-16           P2           P
#            date teamMemberId shiftTypeId
# 100  2026-02-17           F1          AA
# 44   2026-02-17           F4          AA
# 16   2026-02-17           P2           P
# 6    2026-02-17           P3          BB
#            date teamMemberId shiftTypeId
# 101  2026-02-18           F1          AA
# 80   2026-02-18           F2          AA
# 64   2026-02-18           F3          BB
# 28   2026-02-18           P1           P
#            date teamMemberId shiftTypeId
# 102  2026-02-19           F1          AA
# 81   2026-02-19           F2          AA
# 45   2026-02-19           F4          AA
# 124  2026-02-19           M0          AA
#            date teamMemberId shiftTypeId
# 103  2026-02-20           F1          AA
# 46   2026-02-20           F4          AA
# 29   2026-02-20           P1           B
# 17   2026-02-20           P2           P
#            date teamMemberId shiftTypeId
# 104  2026-02-21           F1          AA
# 82   2026-02-21           F2          AA
# 65   2026-02-21           F3          AA
# 47   2026-02-21           F4          AA
# 18   2026-02-21           P2           P
# 7    2026-02-21           P3           A
#            date teamMemberId shiftTypeId
# 105  2026-02-22           F1          AA
# 83   2026-02-22           F2          AA
# 66   2026-02-22           F3          AA
# 48   2026-02-22           F4          AA
# 125  2026-02-22           M0           B
# 30   2026-02-22           P1           P
#            date teamMemberId shiftTypeId
# 106  2026-02-23           F1          AA
# 84   2026-02-23           F2          AA
# 49   2026-02-23           F4          AA
# 126  2026-02-23           M0           B
#           date teamMemberId shiftTypeId
# 85  2026-02-24           F2          AA
# 67  2026-02-24           F3          AA
# 19  2026-02-24           P2           P
# 8   2026-02-24           P3           P
#           date teamMemberId shiftTypeId
# 86  2026-02-25           F2          AA
# 68  2026-02-25           F3          AA
# 31  2026-02-25           P1           P
# 9   2026-02-25           P3           P
#            date teamMemberId shiftTypeId
# 107  2026-02-26           F1          AA
# 87   2026-02-26           F2          AA
# 69   2026-02-26           F3          AA
# 20   2026-02-26           P2           P
#            date teamMemberId shiftTypeId
# 108  2026-02-27           F1          AA
# 88   2026-02-27           F2          AA
# 70   2026-02-27           F3          AA
# 50   2026-02-27           F4          AA
#            date teamMemberId shiftTypeId
# 89   2026-02-28           F2          AA
# 51   2026-02-28           F4          AA
# 127  2026-02-28           M0          AA
# 32   2026-02-28           P1          BB
# 21   2026-02-28           P2          BB
# 10   2026-02-28           P3          BB

# %%
count_table = df.groupby('date').size().reset_index(name='count')
display(count_table)
# Out:
#           date  count
# 0   2026-02-01      6
# 1   2026-02-02      4
# 2   2026-02-03      4
# 3   2026-02-04      4
# 4   2026-02-05      4
# 5   2026-02-06      4
# 6   2026-02-07      6
# 7   2026-02-08      6
# 8   2026-02-09      4
# 9   2026-02-10      4
# 10  2026-02-11      4
# 11  2026-02-12      4
# 12  2026-02-13      4
# 13  2026-02-14      6
# 14  2026-02-15      6
# 15  2026-02-16      4
# 16  2026-02-17      4
# 17  2026-02-18      4
# 18  2026-02-19      4
# 19  2026-02-20      4
# 20  2026-02-21      6
# 21  2026-02-22      6
# 22  2026-02-23      4
# 23  2026-02-24      4
# 24  2026-02-25      4
# 25  2026-02-26      4
# 26  2026-02-27      4
# 27  2026-02-28      6
